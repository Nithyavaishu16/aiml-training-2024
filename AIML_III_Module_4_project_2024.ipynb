# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithyavaishu16/aiml-training-2024/blob/main/AIML_III_Module_4_project_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Students Internship Batch of 2024**
# ### Project for Module: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
##########################
##########################

## TASK-1 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = ## [REQUIRED]
    new_x = ## [REQUIRED]

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append## [REQUIRED])

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
#   File "<ipython-input-7-00154aa77ab8>", line 20
#     gradient = ## [REQUIRED]
#                ^
# SyntaxError: invalid syntax

# %%
import math

# Define the function f(x) (e.g., a quadratic function for simplicity)
def f(x):
    return x**2 + 4*x + 6  # Example: f(x) = x^2 + 4x + 6

# Define the derivative of the function f(x)
def df(x):
    return 2*x + 4  # Example: df(x) = 2x + 4 (derivative of f(x))

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier * gradient

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append(df(new_x))

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 52
# Local minimum occurs at: -1.9999634624590668
# Slope or df(x) value at this point is: 7.307508186649159e-05
# f(x) value or cost at this point is: 2.000000001334992

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
##########################
##########################

## TASK-2 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return  ## [REQUIRED]

def dg(x):
    return ## [REQUIRED]

# %%
import numpy as np
import matplotlib.pyplot as plt

x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return np.sin(x) + 0.5 * x**2  # [REQUIRED] Example: g(x) = sin(x) + 0.5*x^2

def dg(x):
    return np.cos(x) + x  # [REQUIRED] Derivative: dg(x) = cos(x) + x

y = g(x_2)
dy = dg(x_2)


plt.figure(figsize=(10, 6))
plt.plot(x_2, y, label='g(x) = sin(x) + 0.5 * x^2', color='blue')
plt.plot(x_2, dy, label="g'(x) = cos(x) + x", color='red', linestyle='dashed')

plt.title("Function and its Derivative")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier

# %%
import numpy as np
import matplotlib.pyplot as plt


x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return np.sin(x) + 0.5 * x**2  # Example: g(x) = sin(x) + 0.5*x^2

def dg(x):
    return np.cos(x) + x  # Derivative: dg(x) = cos(x) + x


y = g(x_2)
dy = dg(x_2)

fig, axs = plt.subplots(1, 2, figsize=(12, 6))


axs[0].plot(x_2, y, label='g(x) = sin(x) + 0.5 * x^2', color='blue')
axs[0].set_title('Function: g(x)')
axs[0].set_xlabel('x')
axs[0].set_ylabel('g(x)')
axs[0].grid(True)
axs[0].legend()


axs[1].plot(x_2, dy, label="g'(x) = cos(x) + x", color='red', linestyle='dashed')
axs[1].set_title("Derivative: g'(x)")
axs[1].set_xlabel('x')
axs[1].set_ylabel("g'(x)")
axs[1].grid(True)
axs[1].legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.7104341631942704
# Number of steps: 123

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.5,
                                                 multiplier=0.01, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.7332204967465393
# Number of steps: 224

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.7103548074334265
# Number of steps: 97

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
## TASK-4 : Code the same things as they were done for the first two examples

# %%
import numpy as np
import matplotlib.pyplot as plt

x_2 = np.linspace(-2, 2, 1000)

def g1(x):
    return x**3 + 3*x**2 + 2  # Example 1: g(x) = x^3 + 3x^2 + 2

def dg1(x):
    return 3*x**2 + 6*x  # Derivative: g'(x) = 3x^2 + 6x


y1 = g1(x_2)
dy1 = dg1(x_2)

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].plot(x_2, y1, label='g(x) = x^3 + 3x^2 + 2', color='blue')
axs[0].set_title('Function: g(x)')
axs[0].set_xlabel('x')
axs[0].set_ylabel('g(x)')
axs[0].grid(True)
axs[0].legend()


axs[1].plot(x_2, dy1, label="g'(x) = 3x^2 + 6x", color='red', linestyle='dashed')
axs[1].set_title("Derivative: g'(x)")
axs[1].set_xlabel('x')
axs[1].set_ylabel("g'(x)")
axs[1].grid(True)
axs[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  169

# %%
## TASK-5 : Run gradient descent 3 times
## TASK-6 : Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess= 3,
                                                multiplier=0.0005, precision=0.0001, max_iter=n)


mid_gamma =## [REQUIRED]
high_gamma =## [REQUIRED]

# Experiment
insane_gamma = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.25, precision=0.0001, max_iter=n)

# %%
#task-5
import numpy as np

# Define the function and its derivative
def g(x):
    return np.sin(x) + 0.5 * x**2  # Example: g(x) = sin(x) + 0.5*x^2

def dg(x):
    return np.cos(x) + x  # Derivative: dg(x) = cos(x) + x

# Gradient Descent function
def gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter):
    new_x = initial_guess
    previous_x = 0
    step_size = 1
    iterations = 0
    while step_size > precision and iterations < max_iter:
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient
        step_size = abs(new_x - previous_x)
        iterations += 1
    return new_x, iterations

# Run gradient descent 3 times with different multipliers (learning rates)
n = 100

# Low learning rate
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)
print(f'Low learning rate result: {low_gamma}')

# Mid learning rate
mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)  # [REQUIRED]
print(f'Mid learning rate result: {mid_gamma}')

# High learning rate
high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)  # [REQUIRED]
print(f'High learning rate result: {high_gamma}')
# Out:
# Low learning rate result: (2.901527863789199, 100)
# Mid learning rate result: (2.806709090871903, 100)
# High learning rate result: (2.625922703065177, 100)

# %%
#task-6
insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)
print(f'Insane learning rate result: {insane_gamma}')

import matplotlib.pyplot as plt

x_values = np.linspace(-2, 2, 1000)
y_values = g(x_values)

plt.plot(x_values, y_values, label="g(x) = sin(x) + 0.5*x^2")

plt.axvline(x=low_gamma[0], color='green', linestyle='--', label=f'Low gamma (0.0005): {low_gamma[0]:.4f}')
plt.axvline(x=mid_gamma[0], color='blue', linestyle='--', label=f'Mid gamma (0.001): {mid_gamma[0]:.4f}')
plt.axvline(x=high_gamma[0], color='orange', linestyle='--', label=f'High gamma (0.002): {high_gamma[0]:.4f}')
plt.axvline(x=insane_gamma[0], color='red', linestyle='--', label=f'Insane gamma (0.25): {insane_gamma[0]:.4f}')

plt.title("Gradient Descent with Different Learning Rates")
plt.xlabel("x")
plt.ylabel("g(x)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Insane learning rate result: (-0.7389750030608667, 22)

# %%
## TASK-7 : Plot reduction in cost for each iteration
import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def g(x):
    return np.sin(x) + 0.5 * x**2  # Example: g(x) = sin(x) + 0.5*x^2

def dg(x):
    return np.cos(x) + x  # Derivative: dg(x) = cos(x) + x

def gradient_descent(derivative_func, cost_func, initial_guess, multiplier, precision, max_iter):
    new_x = initial_guess
    previous_x = 0
    step_size = 1
    iterations = 0
    costs = [cost_func(new_x)]  # List to keep track of cost at each iteration
    x_values = [new_x]  # List to keep track of x values at each iteration

    while step_size > precision and iterations < max_iter:
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient
        step_size = abs(new_x - previous_x)
        costs.append(cost_func(new_x))  # Record cost at new_x
        x_values.append(new_x)  # Record new_x value
        iterations += 1

    return new_x, costs, x_values

def cost_function(x):
    return g(x)  # Example: cost function is the same as g(x)

n = 100

low_gamma_result, low_gamma_costs, low_gamma_x_values = gradient_descent(dg, cost_function, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)

mid_gamma_result, mid_gamma_costs, mid_gamma_x_values = gradient_descent(dg, cost_function, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)

high_gamma_result, high_gamma_costs, high_gamma_x_values = gradient_descent(dg, cost_function, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)


plt.figure(figsize=(12, 8))

plt.plot(low_gamma_costs, label='Low gamma (0.0005)', color='green')
plt.plot(mid_gamma_costs, label='Mid gamma (0.001)', color='blue')
plt.plot(high_gamma_costs, label='High gamma (0.002)', color='orange')

plt.title('Reduction in Cost for Each Iteration')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
## TASK-8 : Code the same things as they were done for the first two examples
import numpy as np
import matplotlib.pyplot as plt


x_values = np.linspace(-2, 2, 1000)

def g1(x):
    return x**3 + 3*x**2 + 2  # Example 1: g(x) = x^3 + 3x^2 + 2

def dg1(x):
    return 3*x**2 + 6*x  # Derivative: g'(x) = 3x^2 + 6x

y1 = g1(x_values)
dy1 = dg1(x_values)

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].plot(x_values, y1, label='g(x) = x^3 + 3x^2 + 2', color='blue')
axs[0].set_title('Function: g(x)')
axs[0].set_xlabel('x')
axs[0].set_ylabel('g(x)')
axs[0].grid(True)
axs[0].legend()

axs[1].plot(x_values, dy1, label="g'(x) = 3x^2 + 6x", color='red', linestyle='dashed')
axs[1].set_title("Derivative: g'(x)")
axs[1].set_xlabel('x')
axs[1].set_ylabel("g'(x)")
axs[1].grid(True)
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
x_values = np.linspace(-2, 2, 1000)

def g2(x):
    return np.sin(x) + 0.5 * x**2  # Example 2: g(x) = sin(x) + 0.5*x^2

def dg2(x):
    return np.cos(x) + x  # Derivative: g'(x) = cos(x) + x

y2 = g2(x_values)
dy2 = dg2(x_values)


fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].plot(x_values, y2, label='g(x) = sin(x) + 0.5 * x^2', color='blue')
axs[0].set_title('Function: g(x)')
axs[0].set_xlabel('x')
axs[0].set_ylabel('g(x)')
axs[0].grid(True)
axs[0].legend()

axs[1].plot(x_values, dy2, label="g'(x) = cos(x) + x", color='red', linestyle='dashed')
axs[1].set_title("Derivative: g'(x)")
axs[1].set_xlabel('x')
axs[1].set_ylabel("g'(x)")
axs[1].grid(True)
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
# Generating 3D Plot
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-aa5c611162e8> in <cell line: 9>()
#       7 ax.set_zlabel('f(x, y) - Cost', fontsize=20)
#       8
# ----> 9 ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
#      10
#      11 plt.show()
#
# TypeError: f() takes 1 positional argument but 2 were given

# %%
# Generating 3D Plot
# !pip install matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np

# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)

# define the function f(x, y)
def f(x, y):
  return x**2 + y**2

fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

# Call the function f(x, y) with two arguments
ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)

plt.show()
# Out:
# ...
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
import sympy as sp

x, y = sp.symbols('x y')

f = x**2 * y + 3 * x * y**2

df_dx = sp.diff(f, x)  # Partial derivative with respect to x
df_dy = sp.diff(f, y)  # Partial derivative with respect to y

print(f"∂f/∂x = {df_dx}")
print(f"∂f/∂y = {df_dy}")
# Out:
# ∂f/∂x = 2*x*y + 3*y**2
# ∂f/∂y = x**2 + 6*x*y

# %%
a, b = symbols('x, y')
print('Our cost function f(x, y) is: ', f(a, b))
print('Partial derivative wrt x is: ', diff(f(a, b), b))
print('Value of f(x,y) at x=1.8 y=1.0 is: ',
      f(a, b).evalf(subs={a:1.8, b:1.0})) # Python Dictionary
print('Value of partial derivative wrt x: ', diff(f(a, b), a).evalf(subs={a:1.8, b:1.0}))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-076a7a187497> in <cell line: 2>()
#       1 a, b = symbols('x, y')
# ----> 2 print('Our cost function f(x, y) is: ', f(a, b))
#       3 print('Partial derivative wrt x is: ', diff(f(a, b), b))
#       4 print('Value of f(x,y) at x=1.8 y=1.0 is: ',
#       5       f(a, b).evalf(subs={a:1.8, b:1.0})) # Python Dictionary
#
# TypeError: 'Add' object is not callable

# %%
import sympy as sp

a, b = sp.symbols('x, y')
f = x**2 * y + 3 * x * y**2
print('Our cost function f(x, y) is: ', f)
print('Partial derivative wrt x is: ', sp.diff(f, a))
print('Value of f(x,y) at x=1.8 y=1.0 is: ',
      f.subs({a:1.8, b:1.0}))
print('Value of partial derivative wrt x: ', sp.diff(f, a).subs({a:1.8, b:1.0}))
# Out:
# Our cost function f(x, y) is:  x**2*y + 3*x*y**2
# Partial derivative wrt x is:  2*x*y + 3*y**2
# Value of f(x,y) at x=1.8 y=1.0 is:  8.64000000000000
# Value of partial derivative wrt x:  6.60000000000000

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-e2c6c992fb9c> in <cell line: 6>()
#       5
#       6 for n in range(max_iter):
# ----> 7     gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
#       8     gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
#       9     gradients = np.array([gradient_x, gradient_y])
#
# TypeError: 'Add' object is not callable

# %%
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])
a, b = sp.symbols('x, y')
f = x**2 * y + 3 * x * y**2

for n in range(max_iter):
    gradient_x = sp.diff(f, a).subs({a:params[0], b:params[1]})
    gradient_y = sp.diff(f, b).subs({a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients


print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f.subs({a:params[0], b:params[1]}))
# Out:
# <ipython-input-36-706178011658>:11: RuntimeWarning: overflow encountered in multiply
#   params = params - multiplier * gradients
# Values in gradient array [5.11348262751178e+1543884472309552669232216114160315654787304129608644766040324956188422917844832725921566471989462474120598953642930069916931594116978615034
#  6.19458657969180e+1543884472309552669232216114160315654787304129608644766040324956188422917844832725921566471989462474120598953642930069916931594116978615034]
# Minimum occurs at x value of:  -5.11348262751178e+1543884472309552669232216114160315654787304129608644766040324956188422917844832725921566471989462474120598953642930069916931594116978615033
# Minimum occurs at y value of:  -6.19458657969180e+1543884472309552669232216114160315654787304129608644766040324956188422917844832725921566471989462474120598953642930069916931594116978615033
# ...

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Partial derivative functions example 4
def fpx(x, y):
    return ## [REQUIRED]

def fpy(x, y):
    return ## [REQUIRED]

# %%
#task-10
def f(x, y):
    return x**3 + 2*x*y**2  # Example function f(x, y) = x^3 + 2x*y^2


def fpx(x, y):
    return 3*x**2 + 2*y**2  # Partial derivative with respect to x: ∂f/∂x = 3*x^2 + 2*y^2

def fpy(x, y):
    return 4*x*y  # Partial derivative with respect to y: ∂f/∂y = 4*x*y


x_val = 1
y_val = 2

print(f"∂f/∂x at (x={x_val}, y={y_val}) = {fpx(x_val, y_val)}")
print(f"∂f/∂y at (x={x_val}, y={y_val}) = {fpy(x_val, y_val)}")
# Out:
# ∂f/∂x at (x=1, y=2) = 11
# ∂f/∂y at (x=1, y=2) = 8

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [1.24862667e-04 2.09858211e-05]
# Minimum occurs at x value of:  0.0064043063878670365
# Minimum occurs at y value of:  0.0008155147571175164
# The cost is:  2.7119207641851876e-07

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)


# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [0.00073892 0.00016281]
# Minimum occurs at x value of:  0.015474054937764903
# Minimum occurs at y value of:  0.002601524280419824
# The cost is:  3.9146609776035866e-06

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1],
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
import numpy as np

def mse(y, y_hat):

    mse_calc = np.mean((y - y_hat)**2)
    return mse_calc

# Example usage
y = np.array([3, -0.5, 2, 7])         # Actual values
y_hat = np.array([2.5, 0.0, 2, 8])    # Predicted values

# Compute and print the MSE
mse_value = mse(y, y_hat)
print(f"Mean Squared Error (MSE): {mse_value}")
# Out:
# Mean Squared Error (MSE): 0.375

# %%
#print('Manually calculated MSE is:', mse(y_5, y_hat))
#print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
#print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
print('Manually calculated MSE is:', mse(y_5, regr.predict(x_5))) # Use regr.predict(x_5) to calculate y_hat for consistency
print('MSE regression using manual calc is', mean_squared_error(y_5, regr.predict(x_5)))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: 0.9479655759794577
# MSE regression using manual calc is 0.9479655759794577
# MSE regression is 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.9483826526747164
# Min occurs at (i,j): (111, 91)
# Min MSE for Theta 0 at plot_t0[111][91] 0.829145728643216
# Min MSE for Theta 1 at plot_t1[111][91] 1.2311557788944723

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
def grad(x, y, thetas):

    n = y.size

    # Compute the gradient for theta0 and theta1
    theta0_slope = (-2/n) * np.sum(y - (thetas[0] + thetas[1] * x))
    theta1_slope = (-2/n) * np.sum((y - (thetas[0] + thetas[1] * x)) * x)

    # Return the gradients as a numpy array
    return np.array([theta0_slope, theta1_slope])

# Example usage
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 6, 8, 10])
thetas = np.array([0.5, 1.5])

# Compute gradients
gradients = grad(x, y, thetas)
print(f"Gradients: {gradients}")
# Out:
# Gradients: [-2. -8.]

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8532230461743419
# Min occurs at Theta 1: 1.2214935332607393
# MSE is: 0.9479751138321333

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
